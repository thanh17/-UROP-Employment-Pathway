# %% [markdown]
# # Aerospace Engineers to Nannies
#
# ## Dijkstra Pure Distance (least distance):
# ### Distance: 30
# ### Transitions: 9
# ##### path weight: ranking
# Nodes: ['17-2011.00',
#   '17-2199.02',
#   '17-2111.03',
#   '29-9011.00',
#   '11-9161.00',
#   '25-2032.00',
#   '25-2022.00',
#   '25-2012.00',
#   '25-9041.00',
#   '39-9011.01']
#
# 0. Aerospace Engineers
# 1. Validation Engineers
# 2. Product Safety Engineers
# 3. Occupational Health and Safety Specialists
# 4. Emergency Management Directors
# 5. Career/Technical Education Teachers, Secondary School
# 6. Middle School Teachers, Except Special and Career/Technical Education
# 7. Kindergarten Teachers, Except Special Education
# 8. Teacher Assistants
# 9. Nannies
#
# ## Equal Weights (least number of nodes):
# ### Distance: 35.0
# ### Transitions: 6
# ##### path weight: 1
#
# Nodes:
# ['17-2011.00',
#   '17-2111.03',
#   '29-9011.00',
#   '25-2032.00',
#   '25-1194.00',
#   '25-2011.00',
#   '39-9011.01']
#
# 0. Aerospace Engineers
# 1. Product Safety Engineers
# 2. Occupational Health and Safety Specialists
# 3. Career/Technical Education Teachers, Secondary School
# 4. Middle School Teachers, Except Special and Career/Technical Education
# 5. Kindergarten Teachers, Except Special Education
# 6. Nannies
#
# ## Dijkstra-modified High (least distance + nodes):
# ### Distance: 35.0
# ### Transitions: 6
# ##### path weight: ranking + 5.5
# Nodes:
# ['17-2011.00',
#   '17-2111.03',
#   '29-9011.00',
#   '25-2032.00',
#   '25-1194.00',
#   '25-2011.00',
#   '39-9011.01']
#
# 0. Aerospace Engineers
# 1. Product Safety Engineers
# 2. Occupational Health and Safety Specialists
# 3. Career/Technical Education Teachers, Secondary School
# 4. **Vocational Education Teachers, Postsecondary**
# 5. **Preschool Teachers, Except Special Education**
# 6. Nannies
#
# ## Dijkstra-modified Low (least distance + nodes):
# ### Distance: 31.0
# ### Transitions: 8
# ##### path weight: ranking + 1
# Nodes:
# ['17-2011.00',
#   '17-2111.03',
#   '29-9011.00',
#   '11-9161.00',
#   '25-2032.00',
#   '25-2022.00',
#   '25-2012.00',
#   '25-9041.00',
#   '39-9011.01']
#
# 0. Aerospace Engineers
# 1. Product Safety Engineers
# 2. Occupational Health and Safety Specialists
# 3. Emergency Management Directors
# 4. Career/Technical Education Teachers, Secondary School
# 5. Middle School Teachers, Except Special and Career/Technical Education
# 6. Kindergarten Teachers, Except Special Education**
# 7. Teacher Assistants
# 8. Nannies
#
# ## Intersection Path:
# ### Distance: N/A
# ### Transitions: 4
# Nodes:
# ['17-2011.00',
#   '17-2111.03',
#   '29-9011.00',
#   '25-2032.00',
#   '39-9011.01']
#
# 0. Aerospace Engineers
# 1. Product Safety Engineers
# 2. Occupational Health and Safety Specialists
# 3. Career/Technical Education Teachers, Secondary School
# 4. Nannies
#
# ###### *** No paths between Career/Technical Education Teachers, Secondary School (3) and Nannies (4) ***

# %% [markdown]
# # Nannies to Aerospace Engineers
#
# ## Dijkstra Pure Distance (least distance):
# ### Distance: 25.0
# ### Transitions: 8
# ##### path weight: ranking
# Nodes: ['39-9011.01',
#   '21-1093.00',
#   '39-9041.00',
#   '39-1021.00',
#   '53-1021.00',
#   '11-3051.00',
#   '17-2112.00',
#   '17-2071.00',
#   '17-2011.00']
#
# 0. Nannies
# 1. Social and Human Service Assistants
# 2. Residential Advisors
# 3. First-Line Supervisors of Personal Service Workers
# 4. First-Line Supervisors of Helpers, Laborers, and Material Movers, Hand
# 5. Industrial Production Managers
# 6. Industrial Engineers
# 7. Electrical Engineers
# 8. Aerospace Engineers
#
# ## Equal Weights (least number of nodes):
# ### Distance: 42.0
# ### Transitions: 6
# ##### path weight: 1
#
# Nodes:
# ['39-9011.01',
#   '39-9032.00',
#   '25-2023.00',
#   '13-1081.00',
#   '15-1122.00',
#   '17-2199.02',
#   '17-2011.00']
#
# 0. Nannies
# 1. **Recreation Workers**
# 2. **Career/Technical Education Teachers, Middle School**
# 3. **Logisticians**
# 4. **Information Security Analysts**
# 5. **Validation Engineers**
# 6. Aerospace Engineers
#
# ## Dijkstra-modified High (least distance + nodes):
# ### Distance: 29.0
# ### Transitions: 7
# ##### path weight: ranking + 5.5
# Nodes:
# ['39-9011.01',
#   '39-9032.00',
#   '27-2022.00',
#   '41-1012.00',
#   '11-3071.03',
#   '13-1081.01',
#   '17-2071.00',
#   '17-2011.00']
#
# 0. Nannies
# 1. **Recreation Workers**
# 2. **Coaches and Scouts**
# 3. **First-Line Supervisors of Non-Retail Sales Workers**
# 4. **Logistics Managers**
# 5. **Logistics Engineers**
# 6. Electrical Engineers
# 7. Aerospace Engineers
#
# ## Dijkstra-modified low (least distance + nodes):
# ### Distance: 25.0
# ### Transitions: 8
# ##### path weight: ranking + 1
# Nodes:
# ['39-9011.01',
#   '21-1093.00',
#   '39-9041.00',
#   '39-1021.00',
#   '53-1021.00',
#   '11-3051.00',
#   '17-2112.00',
#   '17-2071.00',
#   '17-2011.00']
#
# 0. Nannies
# 1. Social and Human Service Assistants
# 2. Residential Advisors
# 3. First-Line Supervisors of Personal Service Workers
# 4. First-Line Supervisors of Helpers, Laborers, and Material Movers, Hand
# 5. Industrial Production Managers
# 6. Industrial Engineers
# 7. Electrical Engineers
# 8. Aerospace Engineers
#
# ## Intersection Path:
# ### Distance: N/A
# ### Transitions: 2
# Nodes:
# ['39-9011.01',
#   '17-2071.00',
#   '17-2011.00']
#
# 0. Nannies
# 1. Electrical Engineers
# 2. Aerospace Engineers
#
# ###### *** No paths between Nannies (0) and Electrical Engineers (1) ***

# %% [markdown]
# # Computer Programmers to Chief Executives
#
# ## Dijkstra Pure Distance (least distance):
# ### Distance: 24.0
# ### Transitions: 7
# ##### path weight: ranking
# Nodes: ['15-1131.00',
#   '19-4061.00',
#   '13-1141.00',
#   '11-3111.00',
#   '11-3121.00',
#   '11-9151.00',
#   '11-9111.00',
#   '11-1011.00']
#
# 0. Computer Programmers
# 1. Social Science Research Assistants
# 2. Compensation, Benefits, and Job Analysis Specialists
# 3. Compensation and Benefits Managers
# 4. Human Resources Managers
# 5. Social and Community Service Managers
# 6. Medical and Health Services Managers
# 7. Chief Executives
#
# ## Equal Weights (least number of nodes):
# ### Distance: 44.0
# ### Transitions: 5
# ##### path weight: 1
#
# Nodes:
# ['15-1131.00',
#   '43-9111.00',
#   '13-2011.01',
#   '13-2011.02',
#   '11-3031.01',
#   '11-1011.00']
#
# 0. Computer Programmers
# 1. **Statistical Assistants**
# 2. **Accountants**
# 3. **Auditors**
# 4. **Treasurers and Controllers**
# 5. Chief Executives
#
# ## Dijkstra-modified High (least distance + nodes):
# ### Distance: 24.0
# ### Transitions: 7
# ##### path weight: ranking + 5.5
# Nodes: ['15-1131.00',
#   '19-4061.00',
#   '13-1141.00',
#   '11-3111.00',
#   '11-3121.00',
#   '11-9151.00',
#   '11-9111.00',
#   '11-1011.00']
#
# 0. Computer Programmers
# 1. Social Science Research Assistants
# 2. Compensation, Benefits, and Job Analysis Specialists
# 3. Compensation and Benefits Managers
# 4. Human Resources Managers
# 5. Social and Community Service Managers
# 6. Medical and Health Services Managers
# 7. Chief Executives
#
# ## Dijkstra-modified low (least distance + nodes):
# ### Distance: 24.0
# ### Transitions: 7
# ##### path weight: ranking + 1
# Nodes: ['15-1131.00',
#   '19-4061.00',
#   '13-1141.00',
#   '11-3111.00',
#   '11-3121.00',
#   '11-9151.00',
#   '11-9111.00',
#   '11-1011.00']
#
# 0. Computer Programmers
# 1. Social Science Research Assistants
# 2. Compensation, Benefits, and Job Analysis Specialists
# 3. Compensation and Benefits Managers
# 4. Human Resources Managers
# 5. Social and Community Service Managers
# 6. Medical and Health Services Managers
# 7. Chief Executives
#
# ## Intersection Path:
# ### Distance: N/A
# ### Transitions: 2
# Nodes:
# ['15-1131.00',
#   '19-4061.00',
#   '13-1141.00',
#   '11-3111.00',
#   '11-3121.00',
#   '11-9151.00',
#   '11-9111.00',
#   '11-1011.00']
#
# 0. Computer Programmers
# 1. Social Science Research Assistants
# 2. Compensation, Benefits, and Job Analysis Specialists
# 3. Compensation and Benefits Managers
# 4. Human Resources Managers
# 5. Social and Community Service Managers
# 6. Medical and Health Services Managers
# 7. Chief Executives

# %% [markdown]
# # Chief Executive to Computer Programmer
#
# ## Dijkstra Pure Distance (least distance):
# ### Distance: 23.0
# ### Transitions: 7
# ##### path weight: ranking
# Nodes: ['11-1011.00',
#   '11-2022.00',
#   '11-2021.00',
#   '11-2011.00',
#   '27-1011.00',
#   '27-1024.00',
#   '17-1021.00',
#   '15-1131.00']
#
# 0. Chief Executives
# 1. Sales Managers
# 2. Marketing Managers
# 3. Advertising and Promotions Managers
# 4. Art Directors
# 5. Graphic Designers
# 6. Cartographers and Photogrammetrists
# 7. Computer Programmers
#
# ## Equal Weights (least number of nodes):
# ### Distance: 29.0
# ### Transitions: 5
# ##### path weight: 1
#
# Nodes:
# ['11-1011.00',
#   '11-3031.01',
#   '13-1141.00',
#   '13-2053.00',
#   '15-2041.02',
#   '15-1131.00']
#
# 0. Chief Executives
# 1. **Treasurers and Controllers**
# 2. **Compensation, Benefits, and Job Analysis Specialists**
# 3. **Insurance Underwriters**
# 4. **Clinical Data Managers**
# 5. Computer Programmers
#
# ## Dijkstra-modified High (least distance + nodes):
# ### Distance: 29.0
# ### Transitions: 5
# ##### path weight: ranking + 5.5
# Nodes: ['11-1011.00',
#   '11-3031.01',
#   '13-1141.00',
#   '13-2053.00',
#   '15-2041.02',
#   '15-1131.00']
#
# 0. Chief Executives
# 1. **Treasurers and Controllers**
# 2. **Compensation, Benefits, and Job Analysis Specialists**
# 3. **Insurance Underwriters**
# 4. **Clinical Data Managers**
# 5. Computer Programmers
#
# ## Dijkstra-modified low (least distance + nodes):
# ### Distance: 23.0
# ### Transitions: 7
# ##### path weight: ranking + 1
# Nodes: ['11-1011.00',
#   '11-2022.00',
#   '11-2021.00',
#   '11-2011.00',
#   '27-1011.00',
#   '27-1024.00',
#   '17-1021.00',
#   '15-1131.00']
#
# 0. Chief Executives
# 1. Sales Managers
# 2. Marketing Managers
# 3. Advertising and Promotions Managers
# 4. Art Directors
# 5. Graphic Designers
# 6. Cartographers and Photogrammetrists
# 7. Computer Programmers
#
# ## Intersection Path:
# ### Distance: N/A
# ### Transitions: 2
# Nodes:
# ['15-1131.00',
#   '19-4061.00',
#   '13-1141.00',
#   '11-3111.00',
#   '11-3121.00',
#   '11-9151.00',
#   '11-9111.00',
#   '11-1011.00']
#
# 0. Chief Executives
# 1. Computer Programmers
