# %% [markdown]
# # New Career Transitions

# %% [markdown]
# # Waiters and Waitresses (35-3031.00)

# %% [markdown]
# # DEFAULT
#
# 1. Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
# 2. Cashiers
# 3. Cooks, Fast Food
# 4. Combined Food Preparation and Serving Workers, Including Fast Food
# 5. Dining Room and Cafeteria Attendants and Bartender Helpers
# 6. Counter Attendants, Cafeteria, Food Concession, and Coffee Shop
# 7. Stock Clerks, Sales Floor
# 8. Ushers, Lobby Attendants, and Ticket Takers
# 9. Food Servers, Nonrestaurant
# 10. Food Preparation Workers
#
# # OUT
# 1. Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop             -4.776969
# 2. Cashiers                                                             -4.684108
# 3. Dining Room and Cafeteria Attendants and Bartender Helpers           -4.391901
# 4. Food Preparation Workers                                             -4.381614
# 5. Gaming and Sports Book Writers and Runners                           -4.320157
# 6. Combined Food Preparation and Serving Workers, Including Fast Food   -4.307785
# 7. Ushers, Lobby Attendants, and Ticket Takers                          -4.243291
# 8. Cooks, Short Order                                                   -4.223303
# 9. Gaming Dealers                                                       -4.194694
# 10. Counter Attendants, Cafeteria, Food Concession, and Coffee Shop      -4.171333
#
# # SAME ZONES (None)
# 1. Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop   -2.730184
# 2. Cashiers                                                   -2.525328
# 3. Ushers, Lobby Attendants, and Ticket Takers                -2.483467
# 4. Gaming and Sports Book Writers and Runners                 -2.228273
# 5. Stock Clerks, Sales Floor                                  -2.215930
# 6. Bartenders                                                 -2.208239
# 7. Cooks, Short Order                                         -2.185463
# 8. Gaming Dealers                                             -2.117641
# 9. Shampooers                                                 -1.985995
# 10. Nonfarm Animal Caretakers                                  -1.978401
#
# # SAME ZONES (cognitive)
# 1. Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop   -3.742783
# 2. Ushers, Lobby Attendants, and Ticket Takers                -3.407146
# 3. Cashiers                                                   -3.204550
# 4. Cooks, Short Order                                         -2.915215
# 5. Nonfarm Animal Caretakers                                  -2.749400
# 6. Stock Clerks, Sales Floor                                  -2.680055
# 7. Personal Care Aides                                        -2.628160
# 8. Gaming and Sports Book Writers and Runners                 -2.611812
# 9. Transportation Attendants, Except Flight Attendants        -2.552621
# 10. Bartenders                                                 -2.536489
#
# # SAME ZONES (Psychomotor)
#
# 1. Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop   -3.052662
# 2. Gaming and Sports Book Writers and Runners                 -2.959992
# 3. Ushers, Lobby Attendants, and Ticket Takers                -2.895185
# 4. Cashiers                                                   -2.776999
# 5. Stock Clerks, Sales Floor                                  -2.673797
# 6. Nonfarm Animal Caretakers                                  -2.550600
# 7. Cooks, Short Order                                         -2.521071
# 8. Bartenders                                                 -2.476022
# 9. Personal Care Aides                                        -2.462259
# 10. Gaming Dealers                                             -2.455207
#
# # SAME ZONES (Physical)
#
# 1. Bartenders                                                 -2.826835
# 2. Stock Clerks, Sales Floor                                  -2.816672
# 3. Cashiers                                                   -2.705511
# 4. Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop   -2.687158
# 5. Cooks, Short Order                                         -2.541168
# 6. Nonfarm Animal Caretakers                                  -2.411532
# 7. Ushers, Lobby Attendants, and Ticket Takers                -2.386858
# 8. Personal Care Aides                                        -2.347908
# 9. Parking Lot Attendants                                     -2.301820
# 10. Maids and Housekeeping Cleaners                            -2.301745
#
# # SAME ZONES (Sensory)
#
# 1. Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop   -3.717861
# 2. Ushers, Lobby Attendants, and Ticket Takers                -3.398359
# 3. Cashiers                                                   -3.230212
# 4. Gaming and Sports Book Writers and Runners                 -3.134264
# 5. Gaming Dealers                                             -3.126789
# 6. Manicurists and Pedicurists                                -3.002501
# 7. Stock Clerks, Sales Floor                                  -2.893558
# 8. Cooks, Short Order                                         -2.879143
# 9. Retail Salespersons                                        -2.875117
# 10. Personal Care Aides                                        -2.758375

# %% [markdown]
# # Computer Programmer

# %% [markdown]
# # DEFAULT
#
# 1. Software Developers, Systems Software
# 2. Software Developers, Applications
# 3. Database Administrators
# 4. Software Quality Assurance Engineers and Testers
# 5. Computer Systems Analysts
# 6. Web Developers
# 7. *Social Science Research Assistants*
# 8. Geographic Information Systems Technicians
# 9. *Statistical Assistants*
# 10. *Computer Operators*
#
# # OUT
#
# # SAME ZONES (None)
#
#
# # SAME ZONES (cognitive)
#
# # SAME ZONES (Psychomotor)
#
#
#
# # SAME ZONES (Physical)
#
#
#
# # SAME ZONES (Sensory)

# %% [markdown]
# # Retail Salespersons (41-2031)

# %% [markdown]
# # DEFAULT
#
# 1. Hotel, Motel, and Resort Desk Clerks
# 2. Counter and Rental Clerks
# 3. Concierges
# 4. Parts Salespersons
# 5. First-Line Supervisors of Retail Sales Workers
# 6. Floral Designers
# 7. Bartenders
# 8. Public Address System and Other Announcers
# 9. Tellers
# 10. Pharmacy Aides
#
# # OUT
#
#
# # SAME ZONES (None)
#
#
# # SAME ZONES (cognitive)
#
#
# # SAME ZONES (Psychomotor)
#
#
#
# # SAME ZONES (Physical)
#
#
#
# # SAME ZONES (Sensory)

# %% [markdown]
# # Hairdressers, Hairstylists, and Cosmetologists (39-5012.00)

# %% [markdown]
# # DEFAULT
#
# 1. Makeup Artists, Theatrical and Performance
# 2. Floral Designers
# 3. Public Address System and Other Announcers
# 4. Merchandise Displayers and Window Trimmers
# 5. Nannies
# 6. Recreation Workers
# 7. Photographers
# 8. Travel Guides
# 9. Recreational Therapists
# 10. Interior Designers
#
# # OUT
#
#
# # SAME ZONES (None)
#
#
# # SAME ZONES (cognitive)
#
#
# # SAME ZONES (Psychomotor)
#
#
#
# # SAME ZONES (Physical)
#
#
#
# # SAME ZONES (Sensory)

# %% [markdown]
# # Concierges (39-6012.00)

# %% [markdown]
# # DEFAULT
#
# 1. Residential Advisors
# 2. First-Line Supervisors of Personal Service Workers
# 3. Teacher Assistants
# 4. Social and Human Service Assistants
# 5. Childcare Workers
# 6. Preschool Teachers, Except Special Education
# 7. Tour Guides and Escorts
# 8. Personal Care Aides
# 9. Retail Salespersons
# 10. First-Line Supervisors of Retail Sales Workers
#
# # OUT
#
#
# # SAME ZONES (None)
#
#
# # SAME ZONES (cognitive)
#
#
# # SAME ZONES (Psychomotor)
#
#
#
# # SAME ZONES (Physical)
#
#
#
# # SAME ZONES (Sensory)
